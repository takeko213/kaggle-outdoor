# %% [markdown]
# # exp035
# exp031

# %%
# import library
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles
import seaborn as sns
from tqdm.notebook import tqdm
import pathlib
import plotly
import plotly.express as px
import itertools
import lightgbm as lgb
from optuna.integration import lightgbm as optuna_lgb
import simdkalman
import optuna
import pyproj
from pyproj import Proj, transform
from sklearn import metrics
from sklearn.metrics import roc_curve, precision_recall_curve, confusion_matrix, accuracy_score
pd.set_option('display.max_rows', 100)

# %%
ro_th = 50 # 相対移動距離をもとにした異常値除去の閾値
rog_th = 10 # ground_truthをもとにした異常値除去の閾値

# ground_truthをもとにした異常値除去を行うcollection
rog_target = ['2021-04-22-US-SJC-1', '2021-04-29-US-SJC-2', '2021-04-28-US-SJC-1', '2021-04-22-US-SJC-2', '2021-04-29-US-SJC-3',
              '2021-04-28-US-MTV-1', '2021-04-29-US-MTV-1', '2021-03-16-US-RWC-2', '2021-04-28-US-MTV-2', '2021-04-29-US-MTV-2',
              '2021-04-26-US-SVL-2', '2021-03-10-US-SVL-1', '2021-04-26-US-SVL-1',
              '2021-04-21-US-MTV-1', '2021-04-28-US-MTV-1', '2021-04-29-US-MTV-1']

# %%
import ipynb_path

def get_nb_name():
    nb_path = ipynb_path.get()
    nb_name = nb_path.rsplit('/',1)[1].replace('.ipynb','')
    return nb_name

# %%
# directory setting
nb_name = get_nb_name()
INPUT = '../input/google-smartphone-decimeter-challenge'
OUTPUT = '../output/' + nb_name
os.makedirs(OUTPUT, exist_ok=True)

# %% [markdown]
# # utils

# %%
def get_train_score(df, gt):
    gt = gt.rename(columns={'latDeg':'latDeg_gt', 'lngDeg':'lngDeg_gt'})
    df = df.merge(gt, on=['collectionName', 'phoneName', 'millisSinceGpsEpoch'], how='inner')
    # calc_distance_error
    df['err'] = calc_haversine(df['latDeg_gt'], df['lngDeg_gt'], df['latDeg'], df['lngDeg'])
    # calc_evaluate_score
    df['phone'] = df['collectionName'] + '_' + df['phoneName']
    res = df.groupby('phone')['err'].agg([percentile50, percentile95])
    res['p50_p90_mean'] = (res['percentile50'] + res['percentile95']) / 2 
    score = res['p50_p90_mean'].mean()
    return score

# %%
def calc_haversine(lat1, lon1, lat2, lon2):
    """Calculates the great circle distance between two points
    on the earth. Inputs are array-like and specified in decimal degrees.
    """
    RADIUS = 6_367_000
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + \
        np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    dist = 2 * RADIUS * np.arcsin(a**0.5)
    return dist

# %%
def visualize_trafic(df, center, zoom=9):
    fig = px.scatter_mapbox(df,
                            
                            # Here, plotly gets, (x,y) coordinates
                            lat="latDeg",
                            lon="lngDeg",
                            
                            #Here, plotly detects color of series
                            color="phoneName",
                            labels="phoneName",
                            
                            zoom=zoom,
                            center=center,
                            height=600,
                            width=800)
    fig.update_layout(mapbox_style='stamen-terrain')
    fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0})
    fig.update_layout(title_text="GPS trafic")
    fig.show()
    
def visualize_collection(df, collection):
    target_df = df[df['collectionName']==collection].copy()
    lat_center = target_df['latDeg'].mean()
    lng_center = target_df['lngDeg'].mean()
    center = {"lat":lat_center, "lon":lng_center}
    
    visualize_trafic(target_df, center)

# %%
# ground_truth
def get_ground_truth():
    p = pathlib.Path(INPUT)
    gt_files = list(p.glob('train/*/*/ground_truth.csv'))

    gts = []
    for gt_file in gt_files:
        gts.append(pd.read_csv(gt_file))
    ground_truth = pd.concat(gts)

    return ground_truth

# %%
def percentile50(x):
    return np.percentile(x, 50)
def percentile95(x):
    return np.percentile(x, 95)

# %%
class train_result:
    def __init__(self, df):
        self.df = df
        self.gt = get_ground_truth()
        self.bl = pd.read_csv(INPUT + '/' + 'baseline_locations_train.csv')
        
        self.gt = self.gt.rename(columns={'latDeg':'latDeg_gt', 'lngDeg':'lngDeg_gt'})
        self.df = self.df.merge(self.gt, on=['collectionName', 'phoneName', 'millisSinceGpsEpoch'], how='inner')
        self.df['phone'] = self.df['collectionName'] + '_' + self.df['phoneName']
        self.df['err'] =  calc_haversine(self.df['latDeg_gt'], self.df['lngDeg_gt'], self.df['latDeg'], self.df['lngDeg'])
        
        self.phone_res = self.calc_err('phone')
        self.clc_res = self.calc_err('collectionName')
        self.phonename_res = self.calc_err('phoneName')
        
    def calc_err(self, by):
        res = self.df.groupby(by)['err'].agg([percentile50, percentile95])
        res['p50_p90_mean'] = (res['percentile50'] + res['percentile95']) / 2
        return res
    
    @property
    def score(self):
        return self.phone_res['p50_p90_mean'].mean()
    @property
    def raw_data(self):
        return self.df
    @property
    def err(self):
        return self.phone_res
    @property
    def collection_err(self):
        return self.clc_res
    @property
    def phonename_err(self):
        return self.phonename_res
    
    def viz_map(self, collection, show_gt=True, show_bl=True):
        tmp = self.df[self.df['collectionName']==collection][['collectionName', 'phoneName', 'latDeg', 'lngDeg']]
        tmp2 = self.df[self.df['collectionName']==collection][['collectionName', 'phoneName', 'latDeg_gt', 'lngDeg_gt']]
        tmp2 = tmp2.rename(columns={'latDeg_gt':'latDeg', 'lngDeg_gt':'lngDeg'})
        tmp2['phoneName'] = tmp2['phoneName'] + '_GT'
        tmp3 = self.bl[self.bl['collectionName']==collection][['collectionName', 'phoneName', 'latDeg', 'lngDeg']]
        tmp3['phoneName'] = tmp3['phoneName'] + '_BL'
        
        if show_gt:
            tmp = tmp.append(tmp2)
        if show_bl:
            tmp = tmp.append(tmp3)
        visualize_collection(tmp, collection)

# %%
def get_data():
    base_train = pd.read_csv(INPUT + '/' + 'baseline_locations_train.csv')
    base_test = pd.read_csv(INPUT + '/' + 'baseline_locations_test.csv')
    sample_sub = pd.read_csv(INPUT + '/' + 'sample_submission.csv')
    ground_truth = get_ground_truth()
    return base_train, base_test, sample_sub, ground_truth

# %% [markdown]
# # degreeの回帰モデル

# %%
def add_sensor_features(df, accel, gyro, mag, ori):
    # phoneを追加
    df['phone'] = df['collectionName'] + '_' + df['phoneName']
    accel['phone'] = accel['collectionName'] + '_' + accel['phoneName']
    gyro['phone'] = gyro['collectionName'] + '_' + gyro['phoneName']
    mag['phone'] = mag['collectionName'] + '_' + mag['phoneName']
    ori['phone'] = ori['collectionName'] + '_' + ori['phoneName']
    
    # 一定の値しか入っていないphoneを除外しておく
    ori = ori[~ori['phone'].isin(['2021-04-29-US-MTV-1_SamsungS20Ultra', '2021-04-28-US-MTV-1_SamsungS20Ultra', '2021-04-28-US-SJC-1_SamsungS20Ultra', '2021-04-29-US-SJC-2_SamsungS20Ultra',
                                 '2021-04-28-US-MTV-2_SamsungS20Ultra', '2021-04-29-US-SJC-3_SamsungS20Ultra', '2021-04-29-US-MTV-2_SamsungS20Ultra'])]
    
    # phonenameをラベルエンコーディング
    phoneName_map = {'Pixel4':1, 'Pixel4XLModded':2, 'Pixel4XL':3, 'Mi8':4, 'Pixel4Modded':5, 'Pixel5':6, 'SamsungS20Ultra':7}
    df['phoneName_le'] = df['phoneName'].map(phoneName_map)
    
    # utc -> gps
    accel['millisSinceGpsEpoch'] = accel['utcTimeMillis'] - 315964800000 + 18000
    gyro['millisSinceGpsEpoch'] = gyro['utcTimeMillis'] - 315964800000 + 18000
    mag['millisSinceGpsEpoch'] = mag['utcTimeMillis'] - 315964800000 + 18000
    ori['millisSinceGpsEpoch'] = ori['utcTimeMillis'] - 315964800000 + 18000
    
    # resampling追加
    df['secondSinceGpsEpoch'] = df['millisSinceGpsEpoch'] // 1000
    accel['secondSinceGpsEpoch'] = accel['millisSinceGpsEpoch'] // 1000
    gyro['secondSinceGpsEpoch'] = gyro['millisSinceGpsEpoch'] // 1000
    mag['secondSinceGpsEpoch'] = mag['millisSinceGpsEpoch'] // 1000
    ori['secondSinceGpsEpoch'] = ori['millisSinceGpsEpoch'] // 1000
    
    # clipping
    accel[['UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']] = accel.groupby('phone')['UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2'].transform(lambda x: x.clip(x.quantile(0.001), x.quantile(0.999)))
    gyro[['UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec']] = gyro.groupby('phone')['UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec'].transform(lambda x: x.clip(x.quantile(0.001), x.quantile(0.999)))
    mag[['UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT']] = mag.groupby('phone')['UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT'].transform(lambda x: x.clip(x.quantile(0.001), x.quantile(0.999)))
    
    accel = accel.groupby(['phone', 'secondSinceGpsEpoch'])['UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2'].agg(['mean', 'std']).reset_index()
    accel.columns = ['phone', 'secondSinceGpsEpoch', 'UncalAccelXMps2_mean', 'UncalAccelXMps2_std', 'UncalAccelYMps2_mean', 'UncalAccelYMps2_std', 'UncalAccelZMps2_mean', 'UncalAccelZMps2_std']
    gyro = gyro.groupby(['phone', 'secondSinceGpsEpoch'])['UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec'].agg(['mean', 'std']).reset_index()
    gyro.columns = ['phone', 'secondSinceGpsEpoch', 'UncalGyroXRadPerSec_mean', 'UncalGyroXRadPerSec_std', 'UncalGyroYRadPerSec_mean', 'UncalGyroYRadPerSec_std', 'UncalGyroZRadPerSec_mean', 'UncalGyroZRadPerSec_std' ]
    mag = mag.groupby(['phone', 'secondSinceGpsEpoch'])['UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT'].agg(['mean', 'std']).reset_index()
    mag.columns = ['phone', 'secondSinceGpsEpoch', 'UncalMagXMicroT_mean', 'UncalMagXMicroT_std', 'UncalMagYMicroT_mean', 'UncalMagYMicroT_std', 'UncalMagZMicroT_mean', 'UncalMagZMicroT_std']
    ori = ori.groupby(['phone', 'secondSinceGpsEpoch'])['yawDeg', 'rollDeg', 'pitchDeg'].agg(['mean', 'std']).reset_index()
    ori.columns = ['phone', 'secondSinceGpsEpoch', 'yawDeg_mean', 'yawDeg_std', 'rollDeg_mean', 'rollDeg_std', 'pitchDeg_mean', 'pitchDeg_std']
    
    
    # shift特徴量
    for c, i in itertools.product(['UncalAccelXMps2_mean', 'UncalAccelXMps2_std', 'UncalAccelYMps2_mean', 'UncalAccelYMps2_std', 'UncalAccelZMps2_mean', 'UncalAccelZMps2_std'], [1,2,3,-1,-2,-3]):
        col = c+ '_s' + str(i)
        accel[col] = accel[c].shift(i)
        accel[col+'_diff'] = accel[c] - accel[col]
        accel.loc[accel['phone']!=accel['phone'].shift(i), [col, col+'_diff']] = np.nan
    for c, i in itertools.product(['UncalGyroXRadPerSec_mean', 'UncalGyroXRadPerSec_std', 'UncalGyroYRadPerSec_mean', 'UncalGyroYRadPerSec_std', 'UncalGyroZRadPerSec_mean', 'UncalGyroZRadPerSec_std'], [1,2,3,-1,-2,-3]):
        col = c+ '_s' + str(i)
        gyro[col] = gyro[c].shift(i)
        gyro[col+'_diff'] = gyro[c] - gyro[col]
        gyro.loc[gyro['phone']!=gyro['phone'].shift(i), [col, col+'_diff']] = np.nan
    for c, i in itertools.product(['UncalMagXMicroT_mean', 'UncalMagXMicroT_std', 'UncalMagYMicroT_mean', 'UncalMagYMicroT_std', 'UncalMagZMicroT_mean', 'UncalMagZMicroT_std'], [1,2,3,-1,-2,-3]):
        col = c+ '_s' + str(i)
        mag[col] = mag[c].shift(i)
        mag[col+'_diff'] = mag[c] - mag[col]
        mag.loc[mag['phone']!=mag['phone'].shift(i), [col, col+'_diff']] = np.nan
    for c, i in itertools.product(['yawDeg_mean', 'yawDeg_std', 'rollDeg_mean', 'rollDeg_std', 'pitchDeg_mean', 'pitchDeg_std'], [1,2,3,-1,-2,-3]):
        col = c+ '_s' + str(i)
        ori[col] = ori[c].shift(i)
        ori[col+'_diff'] = ori[c] - ori[col]
        ori.loc[ori['phone']!=ori['phone'].shift(i), [col, col+'_diff']] = np.nan
        
    
    df = df.merge(accel, on=['phone', 'secondSinceGpsEpoch'], how='left')
    df = df.merge(gyro, on=['phone', 'secondSinceGpsEpoch'], how='left')
    df = df.merge(mag, on=['phone', 'secondSinceGpsEpoch'], how='left')
    df = df.merge(ori, on=['phone', 'secondSinceGpsEpoch'], how='left')
    
    df.drop(['secondSinceGpsEpoch'], axis=1, inplace=True)
    
    return df

# %%
train, test, sub, gt = get_data()
accel_train = pd.read_csv(INPUT + '/prep/gnss/train/UncalAccel.csv')
gyro_train = pd.read_csv(INPUT + '/prep/gnss/train/UncalGyro.csv')
mag_train = pd.read_csv(INPUT + '/prep/gnss/train/UncalMag.csv')
accel_test = pd.read_csv(INPUT + '/prep/gnss/test/UncalAccel.csv')
gyro_test = pd.read_csv(INPUT + '/prep/gnss/test/UncalGyro.csv')
mag_test = pd.read_csv(INPUT + '/prep/gnss/test/UncalMag.csv')

ori_train = pd.read_csv(INPUT + '/prep/gnss/train/OrientationDeg.csv')
ori_test = pd.read_csv(INPUT + '/prep/gnss/test/OrientationDeg.csv')

train = train.merge(gt[['collectionName', 'phoneName', 'millisSinceGpsEpoch', 'courseDegree']], on=['collectionName', 'phoneName', 'millisSinceGpsEpoch'], how='inner')

train = add_sensor_features(train, accel_train, gyro_train, mag_train, ori_train)
test = add_sensor_features(test, accel_test, gyro_test, mag_test, ori_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:32: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:37: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:39: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:41: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:32: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:37: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:39: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:41: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
target = 'courseDegree'
not_use_cols = ['speedMps', 'collectionName', 'phoneName', 'phone', 'millisSinceGpsEpoch', 'latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM',
                'latDeg_s1', 'latDeg_s2', 'latDeg_s3', 'latDeg_s-1', 'latDeg_s-2',
                'latDeg_s-3', 'lngDeg_s1', 'lngDeg_s2', 'lngDeg_s3', 'lngDeg_s-1',
                'lngDeg_s-2', 'lngDeg_s-3', 'heightAboveWgs84EllipsoidM_s1',
                'heightAboveWgs84EllipsoidM_s2', 'heightAboveWgs84EllipsoidM_s3',
                'heightAboveWgs84EllipsoidM_s-1', 'heightAboveWgs84EllipsoidM_s-2',
                'heightAboveWgs84EllipsoidM_s-3', target]
features = [c for c in train.columns if c not in not_use_cols]

opt_params = {'objective': 'regression',
              'metrics': 'rmse',
              'learning_rate': 0.1, 
              'seed': 42, 
              'feature_pre_filter': False, 
              'lambda_l1': 5.430530747001109e-05, 
              'lambda_l2': 3.4066721259729875, 
              'num_leaves': 136, 
              'feature_fraction': 0.8999999999999999, 
              'bagging_fraction': 1.0, 
              'bagging_freq': 0, 
              'min_child_samples': 20, 
              'num_iterations': 20000, 
              'early_stopping_round': 100}

# %%
collections = train['collectionName'].unique()

oof = pd.DataFrame()
imp = pd.DataFrame()
test_preds = np.zeros(len(test))
n = len(collections)

for collection in collections:
    print('valid : ', collection)
    tr_idx = train[train['collectionName']!=collection].index
    vl_idx = train[train['collectionName']==collection].index
    tr_x, tr_y = train[features].iloc[tr_idx], train[target].iloc[tr_idx]
    vl_x, vl_y = train[features].iloc[vl_idx], train[target].iloc[vl_idx]
    tr_data = lgb.Dataset(tr_x, label=tr_y)
    vl_data = lgb.Dataset(vl_x, label=vl_y)
    
    model = lgb.train(opt_params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=20000, early_stopping_rounds=100, verbose_eval=100)
    vl_pred = model.predict(vl_x, num_iteration=model.best_iteration)
    
    oof_tmp = train.iloc[vl_idx].copy()
    oof_tmp['pred'] = vl_pred
    oof = oof.append(oof_tmp)
    
    imp_tmp = pd.DataFrame()
    imp_tmp['feature'] = model.feature_name()
    imp_tmp['importance'] = model.feature_importance()
    imp_tmp['valid_collection'] = collection
    imp = imp.append(imp_tmp)
    
    pred = model.predict(test[features], num_iteration=model.best_iteration)
    test_preds += pred / n
test['pred'] = test_preds
# Out:
# valid :  2020-05-14-US-MTV-1
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127856, number of used features: 313
# [LightGBM] [Info] Start training from score 208.566938
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.3977	valid_1's rmse: 98.3127
# Early stopping, best iteration is:
# [15]	training's rmse: 52.4148	valid_1's rmse: 97.2251
# valid :  2020-05-14-US-MTV-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.068505 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 128995, number of used features: 313
# [LightGBM] [Info] Start training from score 211.595317
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.7694	valid_1's rmse: 53.0813
# [200]	training's rmse: 40.432	valid_1's rmse: 52.721
# [300]	training's rmse: 39.8781	valid_1's rmse: 52.539
# [400]	training's rmse: 39.5816	valid_1's rmse: 52.3357
# [500]	training's rmse: 39.4071	valid_1's rmse: 52.2891
# [600]	training's rmse: 39.2869	valid_1's rmse: 52.2301
# [700]	training's rmse: 39.208	valid_1's rmse: 52.2257
# Early stopping, best iteration is:
# [610]	training's rmse: 39.2761	valid_1's rmse: 52.2179
# valid :  2020-05-21-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074625 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 129311, number of used features: 313
# [LightGBM] [Info] Start training from score 209.957377
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.3449	valid_1's rmse: 96.3865
# Early stopping, best iteration is:
# [10]	training's rmse: 60.4852	valid_1's rmse: 88.3266
# valid :  2020-05-21-US-MTV-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127583, number of used features: 313
# [LightGBM] [Info] Start training from score 212.887848
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.9303	valid_1's rmse: 40.0466
# Early stopping, best iteration is:
# [62]	training's rmse: 43.2574	valid_1's rmse: 39.557
# valid :  2020-05-29-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.064988 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 125591, number of used features: 313
# [LightGBM] [Info] Start training from score 208.437689
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.9204	valid_1's rmse: 99.278
# Early stopping, best iteration is:
# [11]	training's rmse: 58.901	valid_1's rmse: 92.4846
# valid :  2020-05-29-US-MTV-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075854 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127333, number of used features: 313
# [LightGBM] [Info] Start training from score 211.941354
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.7988	valid_1's rmse: 85.1385
# Early stopping, best iteration is:
# [19]	training's rmse: 50.7882	valid_1's rmse: 83.3672
# valid :  2020-06-04-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 126152, number of used features: 313
# [LightGBM] [Info] Start training from score 207.094229
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.757	valid_1's rmse: 78.8425
# Early stopping, best iteration is:
# [12]	training's rmse: 56.3186	valid_1's rmse: 70.2847
# valid :  2020-06-05-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.072710 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 126185, number of used features: 313
# [LightGBM] [Info] Start training from score 209.519924
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 42.2691	valid_1's rmse: 85.0597
# Early stopping, best iteration is:
# [10]	training's rmse: 62.0786	valid_1's rmse: 83.2116
# valid :  2020-06-05-US-MTV-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.077859 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127781, number of used features: 313
# [LightGBM] [Info] Start training from score 212.684191
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.789	valid_1's rmse: 38.2679
# Early stopping, best iteration is:
# [64]	training's rmse: 42.9728	valid_1's rmse: 37.146
# valid :  2020-06-11-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.078618 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127578, number of used features: 313
# [LightGBM] [Info] Start training from score 209.390947
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.6887	valid_1's rmse: 61.3389
# [200]	training's rmse: 40.2848	valid_1's rmse: 60.7238
# [300]	training's rmse: 39.7376	valid_1's rmse: 60.5765
# [400]	training's rmse: 39.4573	valid_1's rmse: 60.5566
# [500]	training's rmse: 39.2908	valid_1's rmse: 60.4641
# [600]	training's rmse: 39.1799	valid_1's rmse: 60.3185
# [700]	training's rmse: 39.1039	valid_1's rmse: 60.2454
# [800]	training's rmse: 39.0532	valid_1's rmse: 60.2301
# [900]	training's rmse: 39.0156	valid_1's rmse: 60.2165
# [1000]	training's rmse: 38.989	valid_1's rmse: 60.1873
# [1100]	training's rmse: 38.9684	valid_1's rmse: 60.1727
# [1200]	training's rmse: 38.9524	valid_1's rmse: 60.1759
# Early stopping, best iteration is:
# [1120]	training's rmse: 38.9647	valid_1's rmse: 60.1623
# valid :  2020-07-08-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.068386 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 125994, number of used features: 313
# [LightGBM] [Info] Start training from score 207.229868
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.4814	valid_1's rmse: 112.583
# Early stopping, best iteration is:
# [8]	training's rmse: 63.4107	valid_1's rmse: 102.471
# valid :  2020-07-17-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114895 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 129247, number of used features: 313
# [LightGBM] [Info] Start training from score 209.917832
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 40.0661	valid_1's rmse: 89.5697
# Early stopping, best iteration is:
# [55]	training's rmse: 41.795	valid_1's rmse: 89.4474
# valid :  2020-07-17-US-MTV-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079885 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 129600, number of used features: 313
# [LightGBM] [Info] Start training from score 211.185100
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 39.9181	valid_1's rmse: 108.872
# Early stopping, best iteration is:
# [1]	training's rmse: 94.8854	valid_1's rmse: 105.038
# valid :  2020-08-03-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114018 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127358, number of used features: 313
# [LightGBM] [Info] Start training from score 207.836778
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 38.596	valid_1's rmse: 110.029
# Early stopping, best iteration is:
# [1]	training's rmse: 94.8036	valid_1's rmse: 100.84
# valid :  2020-08-06-US-MTV-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.065934 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 126059, number of used features: 313
# [LightGBM] [Info] Start training from score 211.384227
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 34.9329	valid_1's rmse: 125.894
# Early stopping, best iteration is:
# [1]	training's rmse: 94.1388	valid_1's rmse: 109.13
# valid :  2020-09-04-US-SF-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 126128, number of used features: 313
# [LightGBM] [Info] Start training from score 207.616494
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 40.5811	valid_1's rmse: 69.8975
# [200]	training's rmse: 39.2396	valid_1's rmse: 69.6194
# [300]	training's rmse: 38.7006	valid_1's rmse: 69.2027
# [400]	training's rmse: 38.3975	valid_1's rmse: 69.0583
# [500]	training's rmse: 38.2205	valid_1's rmse: 68.9195
# Early stopping, best iteration is:
# [493]	training's rmse: 38.2296	valid_1's rmse: 68.9181
# valid :  2020-09-04-US-SF-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.069790 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 125234, number of used features: 313
# [LightGBM] [Info] Start training from score 212.889968
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 39.5333	valid_1's rmse: 76.591
# [200]	training's rmse: 38.176	valid_1's rmse: 76.3808
# Early stopping, best iteration is:
# [179]	training's rmse: 38.3552	valid_1's rmse: 76.3622
# valid :  2021-01-04-US-RWC-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074256 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 123049, number of used features: 313
# [LightGBM] [Info] Start training from score 211.047945
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 42.1828	valid_1's rmse: 37.7182
# [200]	training's rmse: 41.0808	valid_1's rmse: 36.4664
# [300]	training's rmse: 40.6231	valid_1's rmse: 35.9525
# [400]	training's rmse: 40.3594	valid_1's rmse: 35.8144
# [500]	training's rmse: 40.2262	valid_1's rmse: 35.7263
# [600]	training's rmse: 40.1437	valid_1's rmse: 35.6924
# [700]	training's rmse: 40.0838	valid_1's rmse: 35.6378
# [800]	training's rmse: 40.0439	valid_1's rmse: 35.6087
# [900]	training's rmse: 40.0121	valid_1's rmse: 35.5999
# [1000]	training's rmse: 39.991	valid_1's rmse: 35.572
# [1100]	training's rmse: 39.9755	valid_1's rmse: 35.572
# [1200]	training's rmse: 39.964	valid_1's rmse: 35.5655
# [1300]	training's rmse: 39.9548	valid_1's rmse: 35.5606
# [1400]	training's rmse: 39.9482	valid_1's rmse: 35.5607
# Early stopping, best iteration is:
# [1336]	training's rmse: 39.9522	valid_1's rmse: 35.5571
# valid :  2021-01-04-US-RWC-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067682 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 123766, number of used features: 313
# [LightGBM] [Info] Start training from score 211.044843
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 42.2261	valid_1's rmse: 38.2225
# [200]	training's rmse: 41.0243	valid_1's rmse: 37.5217
# [300]	training's rmse: 40.5441	valid_1's rmse: 37.2059
# [400]	training's rmse: 40.288	valid_1's rmse: 37.0455
# [500]	training's rmse: 40.1387	valid_1's rmse: 36.9349
# [600]	training's rmse: 40.046	valid_1's rmse: 36.8568
# [700]	training's rmse: 39.9805	valid_1's rmse: 36.7883
# [800]	training's rmse: 39.9358	valid_1's rmse: 36.7337
# [900]	training's rmse: 39.9034	valid_1's rmse: 36.7091
# [1000]	training's rmse: 39.8796	valid_1's rmse: 36.6939
# [1100]	training's rmse: 39.8627	valid_1's rmse: 36.6753
# [1200]	training's rmse: 39.8503	valid_1's rmse: 36.6617
# [1300]	training's rmse: 39.841	valid_1's rmse: 36.6506
# [1400]	training's rmse: 39.8341	valid_1's rmse: 36.6407
# [1500]	training's rmse: 39.8286	valid_1's rmse: 36.639
# [1600]	training's rmse: 39.8244	valid_1's rmse: 36.6326
# [1700]	training's rmse: 39.8211	valid_1's rmse: 36.6301
# [1800]	training's rmse: 39.8185	valid_1's rmse: 36.6278
# [1900]	training's rmse: 39.8165	valid_1's rmse: 36.6229
# [2000]	training's rmse: 39.815	valid_1's rmse: 36.6214
# [2100]	training's rmse: 39.8139	valid_1's rmse: 36.6184
# [2200]	training's rmse: 39.8129	valid_1's rmse: 36.6156
# [2300]	training's rmse: 39.8121	valid_1's rmse: 36.6136
# Early stopping, best iteration is:
# [2283]	training's rmse: 39.8122	valid_1's rmse: 36.6131
# valid :  2021-01-05-US-SVL-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093639 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 125702, number of used features: 313
# [LightGBM] [Info] Start training from score 211.644097
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 40.8875	valid_1's rmse: 78.1768
# [200]	training's rmse: 39.547	valid_1's rmse: 77.8359
# [300]	training's rmse: 39.0113	valid_1's rmse: 77.6665
# [400]	training's rmse: 38.7098	valid_1's rmse: 77.4599
# [500]	training's rmse: 38.527	valid_1's rmse: 77.2414
# [600]	training's rmse: 38.4143	valid_1's rmse: 77.186
# [700]	training's rmse: 38.3351	valid_1's rmse: 77.109
# [800]	training's rmse: 38.2782	valid_1's rmse: 77.0705
# [900]	training's rmse: 38.2387	valid_1's rmse: 77.0093
# [1000]	training's rmse: 38.2095	valid_1's rmse: 77.0049
# Early stopping, best iteration is:
# [946]	training's rmse: 38.2241	valid_1's rmse: 76.9846
# valid :  2021-01-05-US-SVL-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127694, number of used features: 313
# [LightGBM] [Info] Start training from score 211.094605
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.55	valid_1's rmse: 66.2828
# [200]	training's rmse: 40.382	valid_1's rmse: 64.5234
# [300]	training's rmse: 39.9213	valid_1's rmse: 63.8005
# [400]	training's rmse: 39.68	valid_1's rmse: 63.3856
# [500]	training's rmse: 39.5279	valid_1's rmse: 63.0279
# [600]	training's rmse: 39.4341	valid_1's rmse: 62.915
# [700]	training's rmse: 39.3682	valid_1's rmse: 62.8207
# [800]	training's rmse: 39.3256	valid_1's rmse: 62.7157
# [900]	training's rmse: 39.2922	valid_1's rmse: 62.6146
# [1000]	training's rmse: 39.2686	valid_1's rmse: 62.5788
# [1100]	training's rmse: 39.2515	valid_1's rmse: 62.5583
# [1200]	training's rmse: 39.2371	valid_1's rmse: 62.5194
# [1300]	training's rmse: 39.2269	valid_1's rmse: 62.5037
# [1400]	training's rmse: 39.2194	valid_1's rmse: 62.4922
# [1500]	training's rmse: 39.2134	valid_1's rmse: 62.476
# [1600]	training's rmse: 39.2087	valid_1's rmse: 62.4697
# [1700]	training's rmse: 39.2052	valid_1's rmse: 62.4664
# [1800]	training's rmse: 39.2026	valid_1's rmse: 62.4563
# [1900]	training's rmse: 39.2004	valid_1's rmse: 62.4519
# [2000]	training's rmse: 39.1987	valid_1's rmse: 62.4462
# [2100]	training's rmse: 39.1974	valid_1's rmse: 62.4433
# [2200]	training's rmse: 39.1964	valid_1's rmse: 62.4383
# [2300]	training's rmse: 39.1955	valid_1's rmse: 62.4349
# [2400]	training's rmse: 39.1948	valid_1's rmse: 62.4333
# [2500]	training's rmse: 39.1943	valid_1's rmse: 62.4323
# [2600]	training's rmse: 39.1939	valid_1's rmse: 62.4329
# Early stopping, best iteration is:
# [2501]	training's rmse: 39.1943	valid_1's rmse: 62.4323
# valid :  2021-03-10-US-SVL-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.077258 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 128296, number of used features: 313
# [LightGBM] [Info] Start training from score 210.870356
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.7367	valid_1's rmse: 150.208
# Early stopping, best iteration is:
# [2]	training's rmse: 89.0981	valid_1's rmse: 87.9419
# valid :  2021-04-15-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.069800 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 124437, number of used features: 313
# [LightGBM] [Info] Start training from score 211.510037
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.8995	valid_1's rmse: 91.9009
# Early stopping, best iteration is:
# [6]	training's rmse: 70.1251	valid_1's rmse: 81.7695
# valid :  2021-04-22-US-SJC-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.072618 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 125626, number of used features: 313
# [LightGBM] [Info] Start training from score 209.561514
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.6155	valid_1's rmse: 164.47
# Early stopping, best iteration is:
# [1]	training's rmse: 94.2098	valid_1's rmse: 110.474
# valid :  2021-04-26-US-SVL-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.072032 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 129272, number of used features: 313
# [LightGBM] [Info] Start training from score 212.006466
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 40.352	valid_1's rmse: 148.231
# Early stopping, best iteration is:
# [1]	training's rmse: 94.6477	valid_1's rmse: 106.966
# valid :  2021-04-28-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.109538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 125377, number of used features: 313
# [LightGBM] [Info] Start training from score 210.743308
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 42.288	valid_1's rmse: 90.3917
# Early stopping, best iteration is:
# [9]	training's rmse: 64.2252	valid_1's rmse: 86.2744
# valid :  2021-04-28-US-SJC-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088897 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 127245, number of used features: 313
# [LightGBM] [Info] Start training from score 211.158257
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.9515	valid_1's rmse: 111.827
# Early stopping, best iteration is:
# [3]	training's rmse: 83.43	valid_1's rmse: 103.569
# valid :  2021-04-29-US-MTV-1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.102518 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 126485, number of used features: 313
# [LightGBM] [Info] Start training from score 213.416685
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.4683	valid_1's rmse: 103.676
# Early stopping, best iteration is:
# [37]	training's rmse: 44.2742	valid_1's rmse: 103.129
# valid :  2021-04-29-US-SJC-2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090137 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 79568
# [LightGBM] [Info] Number of data points in the train set: 126642, number of used features: 313
# [LightGBM] [Info] Start training from score 211.236419
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 41.5619	valid_1's rmse: 74.4524
# Early stopping, best iteration is:
# [52]	training's rmse: 43.3597	valid_1's rmse: 73.4284

# %%
imp_mean = imp.groupby('feature').mean().reset_index()
plt.figure(figsize=(10, 30))
sns.barplot(x="importance", y="feature", data=imp_mean.sort_values(by="importance", ascending=False))
plt.title("Feature Importance")
plt.tight_layout()

# %%
tmp = oof.sample(1000)
plt.scatter(tmp['courseDegree'], tmp['pred'])

# %%
from sklearn.metrics import mean_squared_error

phones = oof['phone'].unique()
for phone in phones:
    tmp = oof[oof['phone']==phone].copy()
    print(phone, np.sqrt(mean_squared_error(tmp['courseDegree'], tmp['pred'])))
# Out:
# 2020-05-14-US-MTV-1_Pixel4 71.25350312693209
# 2020-05-14-US-MTV-1_Pixel4XLModded 117.53017086450629
# 2020-05-14-US-MTV-2_Pixel4 32.08335276246551
# 2020-05-14-US-MTV-2_Pixel4XLModded 89.07032874911742
# 2020-05-21-US-MTV-1_Pixel4 88.32659459988497
# 2020-05-21-US-MTV-2_Pixel4 41.69906969739141
# 2020-05-21-US-MTV-2_Pixel4XL 37.06893595826076
# 2020-05-29-US-MTV-1_Pixel4 86.74570310528814
# 2020-05-29-US-MTV-1_Pixel4XL 71.06683072809393
# 2020-05-29-US-MTV-1_Pixel4XLModded 114.24751746644945
# 2020-05-29-US-MTV-2_Pixel4 80.92141714826836
# 2020-05-29-US-MTV-2_Pixel4XL 85.73970342724381
# 2020-06-04-US-MTV-1_Pixel4 47.18256099890919
# 2020-06-04-US-MTV-1_Pixel4XL 68.82104786646218
# 2020-06-04-US-MTV-1_Pixel4XLModded 88.10586663792512
# 2020-06-05-US-MTV-1_Pixel4 63.45955195069158
# 2020-06-05-US-MTV-1_Pixel4XL 75.54797555362295
# 2020-06-05-US-MTV-1_Pixel4XLModded 119.3041357168205
# 2020-06-05-US-MTV-2_Pixel4 41.17215236524996
# 2020-06-05-US-MTV-2_Pixel4XL 32.48600352157829
# 2020-06-11-US-MTV-1_Pixel4 61.08922592351317
# 2020-06-11-US-MTV-1_Pixel4XL 59.10522052714899
# 2020-07-08-US-MTV-1_Pixel4 87.51268584563665
# 2020-07-08-US-MTV-1_Pixel4XL 132.22437823075975
# 2020-07-08-US-MTV-1_Pixel4XLModded 71.48771737457866
# 2020-07-17-US-MTV-1_Mi8 89.44739098561605
# 2020-07-17-US-MTV-2_Mi8 105.03819930267142
# 2020-08-03-US-MTV-1_Mi8 100.67904117527877
# 2020-08-03-US-MTV-1_Pixel4 100.99843004128859
# 2020-08-06-US-MTV-2_Mi8 108.93455222076072
# 2020-08-06-US-MTV-2_Pixel4 109.71784503089343
# 2020-08-06-US-MTV-2_Pixel4XL 108.7193700092592
# 2020-09-04-US-SF-1_Mi8 100.62703045752916
# 2020-09-04-US-SF-1_Pixel4 18.402173175835788
# 2020-09-04-US-SF-1_Pixel4XL 61.84247987988268
# 2020-09-04-US-SF-2_Mi8 102.23474770950094
# 2020-09-04-US-SF-2_Pixel4 58.41710758712516
# 2020-09-04-US-SF-2_Pixel4XL 34.18032580249949
# 2021-01-04-US-RWC-1_Pixel4 38.14508872897709
# 2021-01-04-US-RWC-1_Pixel4Modded 39.31543800988034
# 2021-01-04-US-RWC-1_Pixel4XL 36.509940563805834
# 2021-01-04-US-RWC-1_Pixel5 26.915544469457775
# 2021-01-04-US-RWC-2_Pixel4 27.71624614614366
# 2021-01-04-US-RWC-2_Pixel4Modded 40.044426797821345
# 2021-01-04-US-RWC-2_Pixel4XL 38.155763391500884
# 2021-01-04-US-RWC-2_Pixel5 39.122243115549864
# 2021-01-05-US-SVL-1_Mi8 105.04555660473702
# 2021-01-05-US-SVL-1_Pixel4 67.88144633592754
# 2021-01-05-US-SVL-1_Pixel4XL 48.84740207528582
# 2021-01-05-US-SVL-1_Pixel5 77.39926469480292
# 2021-01-05-US-SVL-2_Pixel4 66.94174133281882
# 2021-01-05-US-SVL-2_Pixel4Modded 60.59534458937357
# 2021-01-05-US-SVL-2_Pixel4XL 59.57655467548089
# 2021-03-10-US-SVL-1_Pixel4XL 80.48653282949262
# 2021-03-10-US-SVL-1_SamsungS20Ultra 94.70070876911247
# 2021-04-15-US-MTV-1_Pixel4 74.40327692142971
# 2021-04-15-US-MTV-1_Pixel4Modded 57.58708481818095
# 2021-04-15-US-MTV-1_Pixel5 91.15098082457365
# 2021-04-15-US-MTV-1_SamsungS20Ultra 97.47321474985695
# 2021-04-22-US-SJC-1_Pixel4 117.04424840837633
# 2021-04-22-US-SJC-1_SamsungS20Ultra 103.32275674803358
# 2021-04-26-US-SVL-1_Mi8 104.18180756826686
# 2021-04-26-US-SVL-1_Pixel5 109.68468479990865
# 2021-04-28-US-MTV-1_Pixel4 92.61149210154252
# 2021-04-28-US-MTV-1_Pixel5 98.05799641553082
# 2021-04-28-US-MTV-1_SamsungS20Ultra 64.20947380799774
# 2021-04-28-US-SJC-1_Pixel4 110.97944510200273
# 2021-04-28-US-SJC-1_SamsungS20Ultra 95.86082992862659
# 2021-04-29-US-MTV-1_Pixel4 116.39651263992171
# 2021-04-29-US-MTV-1_Pixel5 83.94973876053407
# 2021-04-29-US-MTV-1_SamsungS20Ultra 106.1825486439743
# 2021-04-29-US-SJC-2_Pixel4 93.7310306625365
# 2021-04-29-US-SJC-2_SamsungS20Ultra 45.3346151382542
